# %% [markdown]
# 用到冒号：if,for,def函数，Class

# %%
i = 1
if i>0:
    print(i)
elif i==0:
    print("zero")
else:
    print(-i)
# Out:
# 1

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
def hello():
    """
    Hello World!
    """
    print("Hello World!")
hello()
# Out:
# Hello World!

# %%
class Student(object):
    
    def __init__(self,name,score):  #特殊方法“__init__”前后分别有两个下划线,第一个参数永远是self，
                                    #表示创建的实例本身，可以把各种属性绑定到self，因为self就指向创建的实例本身。
        self.name = name
        self.score = score    #self不需要传，Python解释器自己会把实例变量传进去

    def print_score(self):
        print('%s: %s'% (self.name, self.score))
    
    def get_grade(self):
        if self.score >= 90:
            return 'A'
        elif self.score >= 60:
            return 'B'
        else:
            return 'C'

# %%
bart = Student('Bart Simpson', 59)
bart.print_score()
bart.get_grade()
# Out:
# Bart Simpson: 59
# 'C'

# %%
2^3 #异或，将2和3分别转化为二进制，同一位上数字相同为0，不同为1，再将结果转化为十进制（与，或，非）
# Out:
# 1

# %%
3^3
# Out:
# 0

# %%
2^5  # 2为10,5为101，结果为111，等于7
# Out:
# 7

# %%
3^5
# Out:
# 6

# %%
a = 5
print("G"+"o"*a+"gle")
# Out:
# Gooooogle

# %%
array = ["G"+"o"*n+"gle" for n in range(5)]

# %%
array[2:4]  #python里面的冒号左闭右开
# Out:
# ['Google', 'Gooogle']

# %%
name = "Feng.Li"
len(name)
name1 = name.lower().title().split(".")  #lower将字母小写，upper将字母大写，title将首字母大写，split按指定元素将字符串拆分成list
print(name1)
name2 = name.lower().title().split(" ")
print(name2)
# Out:
# ['Feng', 'Li']
# ['Feng.Li']

# %%
print(type(name))
print(type(name1))
# Out:
# <class 'str'>
# <class 'list'>

# %%
1 % 100
# Out:
# 1

# %%
def isleap(x = 2000):
    """
        To judge x year is a leap year or not.
        
        Usage:
            isleap()  #默认是2000年
            isleap(x)
    """
    if x % 100 == 0:
        if x % 400 == 0:
            print(repr(x)+"年是闰年")
        else:
            print(repr(x)+"年不是闰年")
    elif x % 4 == 0:
        print(repr(x)+"年是闰年")
    else:
        print(repr(x)+"年不是闰年")

# %%
help(isleap)
# Out:
# Help on function isleap in module __main__:
#
# isleap(x=2000)
#     To judge x year is a leap year or not.
#
#     Usage:
#         isleap()  #默认是2000年
#         isleap(x)

# %%
isleap()
isleap(2002)
# Out:
# 2000年是闰年
# 2002年不是闰年

# %%
def findroot(a,b,c):
    """
    To find the roots of ax2+bx+c=0.
    """
    from math import sqrt
    derta = b**2-4*a*c
    if derta > 0:
        x1 = -(b + sqrt(derta))/(2*a)
        x2 = -(b - sqrt(derta))/(2*a)
        print("If a="+repr(a)+",b="+repr(b)+",c="+repr(c)+",the roots are"+repr(x1)+","+repr(x2)+".")
    elif derta == 0:
        x1 = -(b + sqrt(derta))/(2*a)
        print("If a="+repr(a)+",b="+repr(b)+",c="+repr(c)+",the roots are same："+repr(x1)+".")
    else:
        print("If a="+repr(a)+",b="+repr(b)+",c="+repr(c)+",the equation doesn't have real root.")

# %%
findroot(1,-2,1)
# Out:
# If a=1,b=-2,c=1,the roots are same：1.0.

# %%
s = [[1,-2,1],[2,1,4],[2,4,0]]
len(s)
# Out:
# 3

# %%
findroot(s[0][0],s[0][1],s[0][2])
# Out:
# the roots are same as 1.0.

# %%
for i in range(len(s)):
    findroot(s[i][0],s[i][1],s[i][2])
# Out:
# If a=1,b=-2,c=1,the roots are same：1.0.
# If a=2,b=1,c=4,the equation doesn't have real root.
# If a=2,b=4,c=0,the roots are-2.0,-0.0.

# %%
print(range(10))
# Out:
# range(0, 10)

# %%
a=1.2
print(repr(a)+"er")
# Out:
# 1.2er

# %%
def findroot(a,b,c):
    """
    To find the roots of ax2+bx+c=0.
    """
    from math import sqrt
    delta = b**2-4*a*c
    if delta > 0:
        x1 = -(b + sqrt(delta))/(2*a)
        x2 = -(b - sqrt(delta))/(2*a)
        print("If a="+repr(a)+",b="+repr(b)+",c="+repr(c)+",the roots are"+repr(x1)+","+repr(x2)+".")
    elif delta == 0:
        x1 = -(b + sqrt(delta))/(2*a)
        print("If a="+repr(a)+",b="+repr(b)+",c="+repr(c)+",the roots are same："+repr(x1)+".")
    else:
        print("If a="+repr(a)+",b="+repr(b)+",c="+repr(c)+",the equation doesn't have real root.")

s = [[1,-2,1],[2,1,4],[2,4,0],[1,3,2],[3,11,10],[6,-7,-5],[2,15,7],[4,-12,9]]
for i in range(len(s)):
    findroot(s[i][0],s[i][1],s[i][2])
# Out:
# If a=1,b=-2,c=1,the roots are same：1.0.
# If a=2,b=1,c=4,the equation doesn't have real root.
# If a=2,b=4,c=0,the roots are-2.0,-0.0.
# If a=1,b=3,c=2,the roots are-2.0,-1.0.
# If a=3,b=11,c=10,the roots are-2.0,-1.6666666666666667.
# If a=6,b=-7,c=-5,the roots are-0.5,1.6666666666666667.
# If a=2,b=15,c=7,the roots are-7.0,-0.5.
# If a=4,b=-12,c=9,the roots are same：1.5.

# %%
a=1
b=1
c=1
expression = str(a)+"x^2+"+str(b)+"x+"+str(c)+"=0"
print(expression," 的解为: x1 = ",0.2,", x2 = ",0.2,"\n",sep = '')
# Out:
# 1x^2+1x+1=0 的解为: x1 = 0.2, x2 = 0.2

# %%
a=1.222222222222222222
a!=0 and a<0
# Out:
# False

# %%
def findroot(a,b,c):
    """
    To find the roots of ax2+bx+c=0.
    """
    from math import sqrt
    #input函数 
    #a,b,c是否是数值型 numeric
    #a,b,c长度是否一致
    #a是否等于0
    #一个返回值可以用return
    if isinstance(a,(int,float)) and isinstance(b,(int,float)) \
                        and isinstance(c,(int,float)) and a!= 0:
        delta = b**2-4*a*c
        if delta > 0:
            x1 = -(b + sqrt(delta))/(2*a)
            x2 = -(b - sqrt(delta))/(2*a)
            print("If a=",a,",b=",b,",c=",c,",the roots are",x1,",",x2,".")
        elif delta == 0:
            x1 = -(b + sqrt(delta))/(2*a)
            print("If a=",a,",b=",b,",c=",c,",the roots are same：",x1,".")
        else:
            print("If a=",a,",b=",b,",c=",c,",the equation doesn't have real root.")
    else:
        print("Please input three numbers,and 'a' can't be zero.")

s = [[0,-2,1],[2,1,4],['e',4,0],[1,3,2],[3,11,10],[6,-7,-5],[2,15,7],[4,-12,9]]
for i in range(len(s)):
    findroot(s[i][0],s[i][1],s[i][2])
# Out:
# Please input three numbers,and 'a' can't be zero.
# If a= 2 ,b= 1 ,c= 4 ,the equation doesn't have real root.
# Please input three numbers,and 'a' can't be zero.
# If a= 1 ,b= 3 ,c= 2 ,the roots are -2.0 , -1.0 .
# If a= 3 ,b= 11 ,c= 10 ,the roots are -2.0 , -1.6666666666666667 .
# If a= 6 ,b= -7 ,c= -5 ,the roots are -0.5 , 1.6666666666666667 .
# If a= 2 ,b= 15 ,c= 7 ,the roots are -7.0 , -0.5 .
# If a= 4 ,b= -12 ,c= 9 ,the roots are same： 1.5 .

# %%
import random
import numpy as np
import pandas as pd

a = np.array([random.randint(1,30) for i in range(10)])
b = np.array([random.randint(1,30) for i in range(10)])
c = np.array([random.randint(1,30) for i in range(10)])
a1 = -b/(2*a)
delta = (b**2 -4*a*c)/(2*a)
x1 = np.array([])
slv = pd.DataFrame(columns=['a','b','c','是否有解','x1','x2'])
slv['a'] = a
slv['b'] = b
slv['c'] = c
slv['是否有解'] = delta >= 0
i = 0
while i <= len(slv['是否有解']) - 1:
    if slv['是否有解'].iloc[i]:
        x1 = a1[i] + delta[i]
        x2 = a1[i] - delta[i]
        slv['x1'].iloc[i] = x1
        slv['x2'].iloc[i] = x2
    i = i + 1
print(slv)
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#     a   b   c   是否有解       x1    x2
# 0  10  24  22  False      NaN   NaN
# 1  26  25   1   True  9.53846 -10.5
# 2  29  22   9  False      NaN   NaN
# 3   4  13  14  False      NaN   NaN
# 4   5  19  14   True      6.2   -10
# 5   1  12  23   True       20   -32
# 6  22  25  30  False      NaN   NaN
# 7  28  15  13  False      NaN   NaN
# 8   8  23   1   True   29.625 -32.5
# 9  13  15  30  False      NaN   NaN

# %%
def matrixTriIndex(n=3,diag = True,lower = True):
    if lower:
        if diag:
            return [(x,y) for x in range(1,n+1) for y in range(1,n+1) if y <= x]
        else:
            return [(x,y) for x in range(1,n+1) for y in range(1,n+1) if y < x]
    else:
        if diag:
            return [(x,y) for x in range(1,n+1) for y in range(1,n+1) if y >= x]
        else:
            return [(x,y) for x in range(1,n+1) for y in range(1,n+1) if y > x]

# %%
matrixTriIndex(4,False,True)
# Out:
# [(2, 1), (3, 1), (3, 2), (4, 1), (4, 2), (4, 3)]

# %%
def matrixTriIndex(n, diag = True, lower = True):
    """
    To print the indexes of an n-dimensional triangular matrix.
    diag = True/False  --->  print the indexes of diagonal elements or not
    lower = True/False  --->  the lower triangular matrix / the upper triangular matrix
    """
    return [(x,y) for x in range(1,n+1) for y in range(1,n+1)  if (diag and x == y) 
            or (lower and x > y) or (lower == False and x < y)]

# %%
matrixTriIndex(4,True,False)
# Out:
# [(1, 1),
#  (1, 2),
#  (1, 3),
#  (1, 4),
#  (2, 2),
#  (2, 3),
#  (2, 4),
#  (3, 3),
#  (3, 4),
#  (4, 4)]

# %%
help(matrixTriIndex)
# Out:
# Help on function matrixTriIndex in module __main__:
#
# matrixTriIndex(n, diag=True, lower=True)
#     To print the indexes of an n-dimensional triangular matrix.
#     diag = True/False  --->  print the indexes of diagonal elements or not
#     lower = True/False  --->  the lower triangular matrix / the upper triangular matrix

# %%
a=1.0
c=2.33
isinstance(a,(int,float))
isinstance(c,(int,float))
# Out:
# True

# %%
import pandas as pd
data = pd.read_csv("C:\\Users\\Administrator\\Desktop\\stat.csv",delimiter='\t',header=None)

# %%
print(len(data))
print(type(data))
# Out:
# 67
# <class 'pandas.core.frame.DataFrame'>

# %%
import zipfile
data1 = zipfile.ZipFile("C:\\Users\\Administrator\\Desktop\\stat.zip")
type(data1)

# %%
data1.namelist()
# Out:
# ['stat.csv']

# %%
pd.read_csv(data1.open('stat.csv'))
# Out:
#                   Vector Autoregression Estimates  Unnamed: 1  Unnamed: 2  \
# 0                    Date: 03/29/19   Time: 20:27         NaN         NaN
# 1         Sample (adjusted): 1/12/2017 12/31/2018         NaN         NaN
# 2    Included observations: 719 after adjustments         NaN         NaN
# 3    Standard errors in ( ) & t-statistics in [ ]         NaN         NaN
# 4                                             NaN         NaN         NaN
# 5                                             NaN        DLNY       DLNX1
# 6                                        DLNY(-1)    0.823428    0.075775
# 7                                        DLNY(-2)    0.124192   -0.060123
# 8                                        DLNY(-3)    0.080316    0.051819
# 9                                        DLNY(-4)   -0.067252   -0.112605
# 10                                       DLNY(-5)   -0.072467    0.033184
# 11                                       DLNY(-6)   -0.034146     0.01407
# ...

# %%
import os

# %%
os.chdir("C:\\Users\\Administrator\\Desktop")  #切换路径

# %%
datazip = zipfile.ZipFile("data1.zip")
data=pd.read_csv(datazip.open('data.csv'))

# %% [markdown]
# 绘制t分布图

# %%
from scipy.stats import t
t = t.rvs(df = 1,size=500)
fig, ax = plt.subplots(1, 1)
ax.hist(t)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(t.ppf(0.01,1),t.ppf(0.99,1),100)

fig, ax = plt.subplots(1, 1)    #fig = plt.figure()
ax.plot(x, t.pdf(x,1),
        'blue', lw=5, alpha=0.6, label='df=1')

plt.show()

# %%
import pandas as pd
mean,cov=[0,1],[[1,.5],[.5,1]]
data = np.random.multivariate_normal(mean,cov,200)
df = pd.DataFrame(data,columns=["x","y"])

# %%
import seaborn as sns

# %%
sns.load_dataset("titanic")
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...
